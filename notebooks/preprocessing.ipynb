# %%
import os, warnings, numpy as np, pandas as pd, matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

from pathlib import Path

DATA_PATH = Path("../data/raw/data.csv")
SAMPLE_FOR_DEV = 200_000
RANDOM_STATE = 42

ARTIFACTS_DIR = Path("../artifacts")
ARTIFACTS_DIR.mkdir(exist_ok=True)

print(f'Using DATA_PATH="{DATA_PATH.resolve()}"')
print("Artifacts folder:", ARTIFACTS_DIR.resolve())
# Out:
# Using DATA_PATH="/Users/pamudithasenanayake/Downloads/Sliit 3-1/FDM - Fundamentals of Data Mining /FDM_project/data/raw/data.csv"
# Artifacts folder: /Users/pamudithasenanayake/Downloads/Sliit 3-1/FDM - Fundamentals of Data Mining /FDM_project/artifacts

# %%
assert DATA_PATH.exists(), f"CSV not found at {DATA_PATH}"
df = pd.read_csv(DATA_PATH, low_memory=False)
df.head()
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# 0  77985.0    Germany  ...    324.086270         Clothing           Nike
# 1  99071.0         UK  ...    806.707815      Electronics        Samsung
# 2  75929.0  Australia  ...   1063.432799            Books  Penguin Books
# 3  88420.0     Canada  ...   2466.854021       Home Decor     Home Depot
# 4  48704.0         UK  ...    248.553049          Grocery         Nestle
#
#   Product_Type   Feedback  Shipping_Method Payment_Method Order_Status  \
# 0       Shorts  Excellent         Same-Day     Debit Card      Shipped
# 1       Tablet  Excellent         Standard    Credit Card   Processing
# 2   Children's    Average         Same-Day    Credit Card   Processing
# 3        Tools  Excellent         Standard         PayPal   Processing
# 4    Chocolate        Bad         Standard           Cash      Shipped
#
#    Ratings           products
# 0      5.0     Cycling shorts
# 1      4.0         Lenovo Tab
# 2      2.0   Sports equipment
# 3      4.0      Utility knife
# 4      1.0  Chocolate cookies
#
# [5 rows x 30 columns]

# %%
print("Original shape:", df.shape)
df.head(3)

# Optional: sample for faster prototyping
if SAMPLE_FOR_DEV and len(df) > SAMPLE_FOR_DEV:
    df = df.sample(SAMPLE_FOR_DEV, random_state=RANDOM_STATE).reset_index(drop=True)
    print(f"Downsampled to {len(df):,} rows for dev purposes.")

df.describe(include='all').T.head(20)
# Out:
# Original shape: (302010, 30)
# Downsampled to 200,000 rows for dev purposes.
#                      count  unique                        top    freq  \
# Transaction_ID    199786.0     NaN                        NaN     NaN
# Customer_ID       199794.0     NaN                        NaN     NaN
# Name                199757  119661              Michael Smith      96
# Email               199766   46605        Michael70@gmail.com      64
# Phone             199757.0     NaN                        NaN     NaN
# Address             199786  198784  923 Eric Mission Apt. 706       2
# City                199840     130                    Chicago   14356
# State               199814      54                    England   41703
# Zipcode           199793.0     NaN                        NaN     NaN
# Country             199821       5                        USA   63186
# Age               199888.0     NaN                        NaN     NaN
# Gender              199786       2                       Male  124157
# Income              199816       3                     Medium   86223
# Customer_Segment    199854       3                    Regular   96733
# Date                199756     366                  7/31/2023     603
# Year              199746.0     NaN                        NaN     NaN
# Month               199813      12                      April   27435
# Time                199768   77775                   19:04:26      11
# Total_Purchases   199765.0     NaN                        NaN     NaN
# Amount            199755.0     NaN                        NaN     NaN
#
#                                mean                std           min  \
# Transaction_ID       5494520.118847     2595422.271277     1000007.0
# Customer_ID            54994.553525       26001.648657       10000.0
# Name                            NaN                NaN           NaN
# Email                           NaN                NaN           NaN
# Phone             5500601362.951986  2596293808.967087  1000049414.0
# Address                         NaN                NaN           NaN
# City                            NaN                NaN           NaN
# State                           NaN                NaN           NaN
# Zipcode                50280.770998       28985.940994         501.0
# Country                         NaN                NaN           NaN
# Age                        35.50048          15.022026          18.0
# Gender                          NaN                NaN           NaN
# Income                          NaN                NaN           NaN
# Customer_Segment                NaN                NaN           NaN
# Date                            NaN                NaN           NaN
# Year                    2023.164479            0.37071        2023.0
# Month                           NaN                NaN           NaN
# Time                            NaN                NaN           NaN
# Total_Purchases            5.359257           2.866386           1.0
# Amount                   255.039266         141.315227     10.000219
#
#                            25%           50%           75%           max
# Transaction_ID      3246077.75     5500641.5     7734932.5     9999995.0
# Customer_ID            32467.0       54960.5      77497.75       99998.0
# Name                       NaN           NaN           NaN           NaN
# Email                      NaN           NaN           NaN           NaN
# Phone             3253565390.0  5500959657.0  7747866972.0  9999996122.0
# Address                    NaN           NaN           NaN           NaN
# City                       NaN           NaN           NaN           NaN
# State                      NaN           NaN           NaN           NaN
# Zipcode                25360.0       50524.0       75264.0       99949.0
# Country                    NaN           NaN           NaN           NaN
# Age                       22.0          32.0          46.0          70.0
# Gender                     NaN           NaN           NaN           NaN
# Income                     NaN           NaN           NaN           NaN
# Customer_Segment           NaN           NaN           NaN           NaN
# Date                       NaN           NaN           NaN           NaN
# Year                    2023.0        2023.0        2023.0        2024.0
# Month                      NaN           NaN           NaN           NaN
# Time                       NaN           NaN           NaN           NaN
# Total_Purchases            3.0           5.0           8.0          10.0
# Amount              132.750385    255.619672    377.500097    499.997024

# %%
nulls = df.isna().sum().sort_values(ascending=False)
nulls_df = pd.DataFrame({
    "column": nulls.index,
    "null_count": nulls.values,
    "null_pct": (nulls.values / len(df)) * 100
})
display(nulls_df)


dup_count = df.duplicated().sum()
print(f"Full-row duplicates: {dup_count}")


if "Transaction_ID" in df.columns:
    dup_txn = df.duplicated(subset=["Transaction_ID"]).sum()
    print(f"Duplicate Transaction_ID: {dup_txn}")


dtypes_df = pd.DataFrame(df.dtypes, columns=["dtype"]).reset_index().rename(columns={"index":"column"})
display(dtypes_df.head(30))
# Out:
#               column  null_count  null_pct
# 0               Year         254    0.1270
# 1             Amount         245    0.1225
# 2               Date         244    0.1220
# 3               Name         243    0.1215
# 4              Phone         243    0.1215
# 5    Total_Purchases         235    0.1175
# 6              Email         234    0.1170
# 7               Time         232    0.1160
# 8       Total_Amount         226    0.1130
# 9    Shipping_Method         222    0.1110
# 10            Gender         214    0.1070
# 11    Transaction_ID         214    0.1070
# 12           Address         214    0.1070
# 13           Zipcode         207    0.1035
# 14       Customer_ID         206    0.1030
# 15    Payment_Method         197    0.0985
# 16             Month         187    0.0935
# 17  Product_Category         186    0.0930
# 18             State         186    0.0930
# 19            Income         184    0.0920
# 20     Product_Brand         182    0.0910
# 21           Country         179    0.0895
# 22      Order_Status         166    0.0830
# 23              City         160    0.0800
# 24  Customer_Segment         146    0.0730
# 25          Feedback         122    0.0610
# 26           Ratings         122    0.0610
# 27               Age         112    0.0560
# 28      Product_Type           0    0.0000
# 29          products           0    0.0000
# Full-row duplicates: 2
# Duplicate Transaction_ID: 3389
#               column    dtype
# 0     Transaction_ID  float64
# 1        Customer_ID  float64
# 2               Name   object
# 3              Email   object
# 4              Phone  float64
# 5            Address   object
# 6               City   object
# 7              State   object
# 8            Zipcode  float64
# 9            Country   object
# 10               Age  float64
# 11            Gender   object
# 12            Income   object
# 13  Customer_Segment   object
# 14              Date   object
# 15              Year  float64
# 16             Month   object
# 17              Time   object
# 18   Total_Purchases  float64
# 19            Amount  float64
# 20      Total_Amount  float64
# 21  Product_Category   object
# 22     Product_Brand   object
# 23      Product_Type   object
# 24          Feedback   object
# 25   Shipping_Method   object
# 26    Payment_Method   object
# 27      Order_Status   object
# 28           Ratings  float64
# 29          products   object

# %%
def to_snake(name):
    return name.strip().replace(" ","_").replace("/","_").replace("-","_").lower()
df.columns = [to_snake(c) for c in df.columns]


if "date" in df.columns:
    df["date"] = pd.to_datetime(df["date"], errors='coerce')


for col in ["amount","total_amount","ratings","total_purchases","age"]:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')


for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].astype(str).str.strip()


from sklearn.impute import SimpleImputer
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = [c for c in df.columns if c not in num_cols]

df[num_cols] = SimpleImputer(strategy="median").fit_transform(df[num_cols])
df[cat_cols] = SimpleImputer(strategy="most_frequent").fit_transform(df[cat_cols])


before = len(df)
df = df.drop_duplicates().reset_index(drop=True)
print(f"Removed {before - len(df):,} duplicates. New shape: {df.shape}")
# Out:
# Removed 2 duplicates. New shape: (199998, 30)

# %%
if "date" in df.columns:
    df["year_num"] = df["date"].dt.year
    df["month_num"] = df["date"].dt.month
    df["dayofweek"] = df["date"].dt.dayofweek
    df["is_weekend"] = df["dayofweek"].isin([5,6]).astype(int)

# Clip extreme amounts
for col in ["amount","total_amount"]:
    if col in df.columns:
        q1, q99 = df[col].quantile([0.01,0.99])
        df[col+"_clipped"] = df[col].clip(q1,q99)

# Simple RFM features
if {"customer_id","date","amount"}.issubset(df.columns):
    last_date = df["date"].max()
    cust_grp = df.groupby("customer_id").agg(
        last_purchase=("date","max"),
        frequency=("transaction_id","nunique") if "transaction_id" in df.columns else ("customer_id","count"),
        monetary=("amount","sum")
    )
    cust_grp["recency_days"] = (last_date - cust_grp["last_purchase"]).dt.days
    df = df.merge(cust_grp[["recency_days","frequency","monetary"]].reset_index(), on="customer_id", how="left")

# Top-K brand/category
if "product_brand" in df.columns:
    top_brands = df["product_brand"].value_counts().index[:30]
    df["product_brand_top"] = np.where(df["product_brand"].isin(top_brands), df["product_brand"], "OTHER")
if "product_category" in df.columns:
    top_cats = df["product_category"].value_counts().index[:30]
    df["product_category_top"] = np.where(df["product_category"].isin(top_cats), df["product_category"], "OTHER")

print("Feature engineering done. Current shape:", df.shape)
df.head(3)
# Out:
# Feature engineering done. Current shape: (199998, 41)
#    transaction_id  customer_id               name               email  \
# 0       8973042.0      20082.0  Ronald Williamson   David75@gmail.com
# 1       6700726.0      59044.0        Julie Yoder  Adrian66@gmail.com
# 2       9007686.0      32393.0   Isaac Livingston   Robyn24@gmail.com
#
#           phone                      address        city            state  \
# 0  3.740098e+09  4618 Pamela Wells Suite 878  Portsmouth          England
# 1  4.959731e+09  5158 Russell Creek Apt. 082      Darwin  New South Wales
# 2  6.717169e+09            06198 Stephen Row   Frankfurt           Berlin
#
#    zipcode    country  ...  month_num dayofweek is_weekend amount_clipped  \
# 0   8805.0         UK  ...         11         2          0     143.404730
# 1  71099.0  Australia  ...          1         0          0     103.655237
# 2  83860.0    Germany  ...          1         2          0     429.278597
#
#   total_amount_clipped  recency_days frequency     monetary  \
# 0          1003.833112            12         4  1275.469378
# 1           103.655237            26         4  1145.523341
# 2           429.278597            50         5  1436.608975
#
#    product_brand_top  product_category_top
# 0               Zara              Clothing
# 1              Apple           Electronics
# 2            Samsung           Electronics
#
# [3 rows x 41 columns]
